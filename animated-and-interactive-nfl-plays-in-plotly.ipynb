# %%
import pandas as pd
import numpy as np

# Read In csvs
games = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2023/games.csv")
plays = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2023/plays.csv")
players = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2023/players.csv")
week1 = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2023/week1.csv")
pffScoutingData = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2023/pffScoutingData.csv")
joined_all = pd.merge(games,plays,how="inner",on = "gameId")
joined_all = pd.merge(joined_all,week1,how="inner",on=["gameId","playId"])
# left join on players to keep football records
joined_all = pd.merge(joined_all,players,how="left",on = "nflId")
play_focus = 97
focused_df = joined_all[(joined_all.playId==play_focus)]

# %%
import plotly.graph_objects as go
fig = go.Figure( layout_yaxis_range=[0,53.3], layout_xaxis_range=[0,120])

colors = {"TB":'#D50A0A',
          "DAL":'#003594',
          "football":'#CBB67C'
        }
for team in focused_df.team.unique():
    plot_df = focused_df[(focused_df.team==team)&(focused_df.frameId==1)]
    fig.add_trace(go.Scatter(x=plot_df["x"], y=plot_df["y"],mode = 'markers',marker_color=colors[team],name=team))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a9883ef0-d293-4f64-afc2-9add233328f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9883ef0-d293-4f64-afc2-9add233328f3")) {                    Plotly.newPlot(                        "a9883ef0-d293-4f64-afc2-9add233328f3",                        [{"marker":{"color":"#D50A0A"},"mode":"markers","name":"TB","x":[37.77,41.08,40.99,37.54,42.18,42.01,41.55,41.95,40.09,41.42,41.15],"y":[24.22,29.15,36.74,22.26,23.97,16.19,26.89,25.66,36.72,22.63,21.36],"type":"scatter"},{"marker":{"color":"#003594"},"mode":"markers","name":"DAL","x":[43.66,44.03,44.59,43.49,44.5,43.47,58.6,48.36,43.5,43.71,43.69],"y":[18.7,32.69,29.62,37.55,37.78,25.14,27.33,22.8,16.27,21.88,26.67],"type":"scatter"},{"marker":{"color":"#CBB67C"},"mode":"markers","name":"football","x":[42.92],"y":[24.04],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmo ...

# %%
colors = {
    'ARI':"#97233F", 
    'ATL':"#A71930", 
    'BAL':'#241773', 
    'BUF':"#00338D", 
    'CAR':"#0085CA", 
    'CHI':"#C83803", 
    'CIN':"#FB4F14", 
    'CLE':"#311D00", 
    'DAL':'#003594',
    'DEN':"#FB4F14", 
    'DET':"#0076B6", 
    'GB':"#203731", 
    'HOU':"#03202F", 
    'IND':"#002C5F", 
    'JAX':"#9F792C", 
    'KC':"#E31837", 
    'LA':"#003594", 
    'LAC':"#0080C6", 
    'LV':"#000000",
    'MIA':"#008E97", 
    'MIN':"#4F2683", 
    'NE':"#002244", 
    'NO':"#D3BC8D", 
    'NYG':"#0B2265", 
    'NYJ':"#125740", 
    'PHI':"#004C54", 
    'PIT':"#FFB612", 
    'SEA':"#69BE28", 
    'SF':"#AA0000",
    'TB':'#D50A0A', 
    'TEN':"#4B92DB", 
    'WAS':"#5A1414", 
    'football':'#CBB67C'
}

# %%
#TODO:
# Add Useful Player Labels
# Add ability to keep or remove the extra stuff (line markers etc)
# Add Team Colors to dict
# Turn into Function 

def animate_play(tracking_df, play_df,players,pffScoutingData, gameId,playId):
    selected_play_df = play_df[(play_df.playId==playId)&(play_df.gameId==gameId)].copy()
    
    tracking_players_df = pd.merge(tracking_df,players,how="left",on = "nflId")
    tracking_players_df = pd.merge(tracking_players_df,pffScoutingData,how="left",on = ["nflId","playId","gameId"])
    selected_tracking_df = tracking_players_df[(tracking_players_df.playId==playId)&(tracking_players_df.gameId==gameId)].copy()

    sorted_frame_list = selected_tracking_df.frameId.unique()
    sorted_frame_list.sort()

    # get play General information 
    line_of_scrimmage = selected_play_df.absoluteYardlineNumber.values[0]
    first_down_marker = line_of_scrimmage + selected_play_df.yardsToGo.values[0]
    down = selected_play_df.down.values[0]
    quarter = selected_play_df.quarter.values[0]
    gameClock = selected_play_df.gameClock.values[0]
    playDescription = selected_play_df.playDescription.values[0]
    # Handle case where we have a really long Play Description and want to split it into two lines
    if len(playDescription.split(" "))>15 and len(playDescription)>115:
        playDescription = " ".join(playDescription.split(" ")[0:16]) + "<br>" + " ".join(playDescription.split(" ")[16:])

    # initialize plotly start and stop buttons for animation
    updatemenus_dict = [
        {
            "buttons": [
                {
                    "args": [None, {"frame": {"duration": 100, "redraw": False},
                                "fromcurrent": True, "transition": {"duration": 0}}],
                    "label": "Play",
                    "method": "animate"
                },
                {
                    "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                      "mode": "immediate",
                                      "transition": {"duration": 0}}],
                    "label": "Pause",
                    "method": "animate"
                }
            ],
            "direction": "left",
            "pad": {"r": 10, "t": 87},
            "showactive": False,
            "type": "buttons",
            "x": 0.1,
            "xanchor": "right",
            "y": 0,
            "yanchor": "top"
        }
    ]
    # initialize plotly slider to show frame position in animation
    sliders_dict = {
        "active": 0,
        "yanchor": "top",
        "xanchor": "left",
        "currentvalue": {
            "font": {"size": 20},
            "prefix": "Frame:",
            "visible": True,
            "xanchor": "right"
        },
        "transition": {"duration": 300, "easing": "cubic-in-out"},
        "pad": {"b": 10, "t": 50},
        "len": 0.9,
        "x": 0.1,
        "y": 0,
        "steps": []
    }


    frames = []
    for frameId in sorted_frame_list:
        data = []
        # Add Numbers to Field 
        data.append(
            go.Scatter(
                x=np.arange(20,110,10), 
                y=[5]*len(np.arange(20,110,10)),
                mode='text',
                text=list(map(str,list(np.arange(20, 61, 10)-10)+list(np.arange(40, 9, -10)))),
                textfont_size = 30,
                textfont_family = "Courier New, monospace",
                textfont_color = "#ffffff",
                showlegend=False,
                hoverinfo='none'
            )
        )
        data.append(
            go.Scatter(
                x=np.arange(20,110,10), 
                y=[53.5-5]*len(np.arange(20,110,10)),
                mode='text',
                text=list(map(str,list(np.arange(20, 61, 10)-10)+list(np.arange(40, 9, -10)))),
                textfont_size = 30,
                textfont_family = "Courier New, monospace",
                textfont_color = "#ffffff",
                showlegend=False,
                hoverinfo='none'
            )
        )
        # Add line of scrimage 
        data.append(
            go.Scatter(
                x=[line_of_scrimmage,line_of_scrimmage], 
                y=[0,53.5],
                line_dash='dash',
                line_color='blue',
                showlegend=False,
                hoverinfo='none'
            )
        )
        # Add First down line 
        data.append(
            go.Scatter(
                x=[first_down_marker,first_down_marker], 
                y=[0,53.5],
                line_dash='dash',
                line_color='yellow',
                showlegend=False,
                hoverinfo='none'
            )
        )
        # Plot Players
        for team in selected_tracking_df.team.unique():
            plot_df = selected_tracking_df[(selected_tracking_df.team==team)&(selected_tracking_df.frameId==frameId)].copy()
            if team != "football":
                hover_text_array=[]
                for nflId in plot_df.nflId:
                    selected_player_df = plot_df[plot_df.nflId==nflId]
                    hover_text_array.append("nflId:{}<br>displayName:{}<br>Position:{}<br>Role:{}".format(selected_player_df["nflId"].values[0],
                                                                                      selected_player_df["displayName"].values[0],
                                                                                      selected_player_df["pff_positionLinedUp"].values[0],
                                                                                      selected_player_df["pff_role"].values[0]))
                data.append(go.Scatter(x=plot_df["x"], y=plot_df["y"],mode = 'markers',marker_color=colors[team],name=team,hovertext=hover_text_array,hoverinfo="text"))
            else:
                data.append(go.Scatter(x=plot_df["x"], y=plot_df["y"],mode = 'markers',marker_color=colors[team],name=team,hoverinfo='none'))
        # add frame to slider
        slider_step = {"args": [
            [frameId],
            {"frame": {"duration": 100, "redraw": False},
             "mode": "immediate",
             "transition": {"duration": 0}}
        ],
            "label": str(frameId),
            "method": "animate"}
        sliders_dict["steps"].append(slider_step)
        frames.append(go.Frame(data=data, name=str(frameId)))

    scale=10
    layout = go.Layout(
        autosize=False,
        width=120*scale,
        height=60*scale,
        xaxis=dict(range=[0, 120], autorange=False, tickmode='array',tickvals=np.arange(10, 111, 5).tolist(),showticklabels=False),
        yaxis=dict(range=[0, 53.3], autorange=False,showgrid=False,showticklabels=False),

        plot_bgcolor='#00B140',
        # Create title and add play description at the bottom of the chart for better visual appeal
        title=f"GameId: {gameId}, PlayId: {playId}<br>{gameClock} {quarter}Q"+"<br>"*19+f"{playDescription}",
        updatemenus=updatemenus_dict,
        sliders = [sliders_dict]
    )

    fig = go.Figure(
        data=frames[0]["data"],
        layout= layout,
        frames=frames[1:]
    )
    # Create First Down Markers 
    for y_val in [0,53]:
        fig.add_annotation(
                x=first_down_marker,
                y=y_val,
                text=str(down),
                showarrow=False,
                font=dict(
                    family="Courier New, monospace",
                    size=16,
                    color="black"
                    ),
                align="center",
                bordercolor="black",
                borderwidth=2,
                borderpad=4,
                bgcolor="#ff7f0e",
                opacity=1
                )

    return fig

# %%
animate_play(week1,plays,players,pffScoutingData,2021090900,97).show()
# Out:
# <div>                            <div id="5920e942-dd35-45f7-b91c-c5b16dffe121" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5920e942-dd35-45f7-b91c-c5b16dffe121")) {                    Plotly.newPlot(                        "5920e942-dd35-45f7-b91c-c5b16dffe121",                        [{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[5,5,5,5,5,5,5,5,5],"type":"scatter"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"blue","dash":"dash"},"showlegend":false,"x":[43.0,43.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"yellow","dash":"dash"},"showlegend":false,"x":[45.0,45.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:25511.0\u003cbr\u003edisplayName:Tom Brady\u003cbr\u003ePosition:QB\u003cbr\u003eRole:Pass","nflId:35481.0\u003cbr\u003edisplayName:Rob Gronkowski\u003cbr\u003ePosition:TE-L\u003cbr\u003eRole:Pass Route","nflId:35634.0\u003cbr\u003edisplayName:Antonio Brown\u003cbr\u003ePosition:LWR\u003cbr\u003eRole:Pass Route","nflId:39985.0\u003cbr\u003edisplayName:Giovani Bernard\u003cbr\u003ePosition:HB-R\u003cbr\u003eRole:Pass Route","nflId:40151.0\u003cbr\u003edisplayName:Ryan Jensen\u003cbr\u003ePosition:C\u003cbr\u003eRole:Pass Block","nflId:41233.0\u003cbr\u003edisplayName:Mike Evans\u003cbr\u003ePosition:RWR\u003cbr\u003eRole:Pass Route","nflId:42377.0\u003cbr\u003edisplayName:Donovan Smith\u003cbr\u003ePosition:LT\u003cbr\u003eRole:Pass Block","nflId:42404.0\u003cbr\u003edisplayName:Ali Marpet\u003cbr\u003ePosition:LG\u003cbr\u003eRole:Pass Block","nflId:44896.0\u003cbr\u003edisplayName:Chris Godwin\u003cbr\u003ePosition:SLWR\u003cbr\u003eRole:Pass Route","nflId:46163.0\u003cbr\u003edisplayName:Alex Cappa\u003cbr\u003ePosition:RG\u003cbr\u003eRole:Pass Block","nflId:52421.0\u003cbr\u003edisplayName:Tristan Wirfs\u003cbr\u003ePosition:RT\u003cbr\u003eRole:Pass Block"],"marker":{"color":"#D50A0A"},"mode":"markers","name":"TB","x":[37.77,41.08,40.99,37.54,42.18,42.01,41.55,41.95,40.09,41.42,41.15],"y":[24.22,29.15,36.74,22.26,23.97,16.19,26.89,25.66,36.72,22.63,21.36],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:41263.0\u003cbr\u003edisplayName:Demarcus Lawrence\u003cbr\u003ePosition:LEO\u003cbr\u003eRole:Pass Rush","nflId:42403.0\u003cbr\u003edisplayName:Randy Gregory\u003cbr\u003ePosition:ROLB\u003cbr\u003eRole:Pass Rush","nflId:43306.0\u003cbr\u003edisplayName:Keanu Neal\u003cbr\u003ePosition:ROLB\u003cbr\u003eRole:Coverage","nflId:43478.0\u003cbr\u003edisplayName:Anthony Brown\u003cbr\u003ePosition:RCB\u003cbr\u003eRole:Coverage","nflId:44904.0\u003cbr\u003edisplayName:Jourdan Lewis\u003cbr\u003ePosition:SCBR\u003cbr\u003eRole:Coverage","nflId:44955.0\u003cbr\u003edisplayName:Carlos Watkins\u003cbr\u003ePosition:DRT\u003cbr\u003eRole:Pass Rush","nflId:44962.0\u003cbr\u003edisplayName:Damontae Kazee\u003cbr\u003ePosition:FS\u003cbr\u003eRole:Coverage","nflId:47996.0\u003cbr\u003edisplayName:Donovan Wilson\u003cbr\u003ePosition:LILB\u003cbr\u003eRole:Coverage","nflId:52459.0\u003cbr\u003edisplayName:Trevon Diggs\u003cbr\u003ePosition:LCB\u003cbr\u003eRole:Coverage","nflId:53441.0\u003cbr\u003edisplayName:Micah Parsons\u003cbr\u003ePosition:LILB\u003cbr\u003eRole:Pass Rush","nflId:53504.0\u003cbr\u003edisplayName:Osa Odighizuwa\u003cbr\u003ePosition:RE\u003cbr\u003eRole:Pass Rush"] ...

# %%
#Select random plays from 5 games
import random
for gameId in week1.gameId.unique()[0:5].tolist():
    plays_list = week1[week1.gameId==gameId].playId.unique().tolist()
    playId = random.choice(plays_list)
    animate_play(week1,plays,players,pffScoutingData,gameId,playId).show()
# Out:
# <div>                            <div id="fea2a0f6-3675-46c6-8262-ca561743a9cc" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fea2a0f6-3675-46c6-8262-ca561743a9cc")) {                    Plotly.newPlot(                        "fea2a0f6-3675-46c6-8262-ca561743a9cc",                        [{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[5,5,5,5,5,5,5,5,5],"type":"scatter"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"blue","dash":"dash"},"showlegend":false,"x":[91.0,91.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"yellow","dash":"dash"},"showlegend":false,"x":[92.0,92.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:35441.0\u003cbr\u003edisplayName:Ndamukong Suh\u003cbr\u003ePosition:DLT\u003cbr\u003eRole:Coverage","nflId:35454.0\u003cbr\u003edisplayName:Jason Pierre-Paul\u003cbr\u003ePosition:ROLB\u003cbr\u003eRole:Pass Rush","nflId:38588.0\u003cbr\u003edisplayName:Lavonte David\u003cbr\u003ePosition:LLB\u003cbr\u003eRole:Coverage","nflId:41338.0\u003cbr\u003edisplayName:Ross Cockrell\u003cbr\u003ePosition:SCBoL\u003cbr\u003eRole:Pass Rush","nflId:41915.0\u003cbr\u003edisplayName:Shaquil Barrett\u003cbr\u003ePosition:LOLB\u003cbr\u003eRole:Pass Rush","nflId:46081.0\u003cbr\u003edisplayName:Vita Vea\u003cbr\u003ePosition:DRT\u003cbr\u003eRole:Coverage","nflId:46132.0\u003cbr\u003edisplayName:Carlton Davis\u003cbr\u003ePosition:RCB\u003cbr\u003eRole:Pass Rush","nflId:47788.0\u003cbr\u003edisplayName:Devin White\u003cbr\u003ePosition:RLB\u003cbr\u003eRole:Coverage","nflId:47877.0\u003cbr\u003edisplayName:Jamel Dean\u003cbr\u003ePosition:LCB\u003cbr\u003eRole:Coverage","nflId:47882.0\u003cbr\u003edisplayName:Mike Edwards\u003cbr\u003ePosition:SCBoL\u003cbr\u003eRole:Coverage","nflId:52453.0\u003cbr\u003edisplayName:Antoine Winfield\u003cbr\u003ePosition:FS\u003cbr\u003eRole:Coverage"],"marker":{"color":"#D50A0A"},"mode":"markers","name":"TB","x":[90.11,90.42,87.51,89.83,90.05,89.78,89.9,87.9,84.95,81.12,80.26],"y":[25.81,20.13,26.45,31.45,28.52,23.24,15.66,20.6,36.96,30.13,21.76],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:37082.0\u003cbr\u003edisplayName:Tyron Smith\u003cbr\u003ePosition:LT\u003cbr\u003eRole:Pass Block","nflId:42347.0\u003cbr\u003edisplayName:Amari Cooper\u003cbr\u003ePosition:RWR\u003cbr\u003eRole:Pass Route","nflId:42654.0\u003cbr\u003edisplayName:La'el Collins\u003cbr\u003ePosition:RT\u003cbr\u003eRole:Pass Block","nflId:43293.0\u003cbr\u003edisplayName:Ezekiel Elliott\u003cbr\u003ePosition:LWR\u003cbr\u003eRole:Pass Route","nflId:43424.0\u003cbr\u003edisplayName:Dak Prescott\u003cbr\u003ePosition:QB\u003cbr\u003eRole:Pass","nflId:46119.0\u003cbr\u003edisplayName:Connor Williams\u003cbr\u003ePosition:LG\u003cbr\u003eRole:Pass Block","nflId:46206.0\u003cbr\u003edisplayName:Dalton Schultz\u003cbr\u003ePosition:SRiWR\u003cbr\u003eRole:Pass Route","nflId:46277.0\u003cbr\u003edisplayName:Cedrick Wilson\u003cbr\u003ePosition:SRoWR\u003cbr\u003eRole:Pass Route","nflId:47873.0\u003cbr\u003edisplayName:Connor McGovern\u003cbr\u003ePosition:RG\u003cbr\u003eRole:Pass Block","nflId:52425.0\u003cbr\u003edisplayName:CeeDee Lamb\u003cbr\u003ePosition:HB-R\u003cbr\u003eRole:Pass Route","nflId:52554.0\u003cbr\u003edisplayName:Tyler Biadasz\u003cbr\u003ePosition:C\u003cbr\u003eRole:Pas ...
# <div>                            <div id="806fb59b-f853-4ac7-ba14-d6015eef2cfe" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("806fb59b-f853-4ac7-ba14-d6015eef2cfe")) {                    Plotly.newPlot(                        "806fb59b-f853-4ac7-ba14-d6015eef2cfe",                        [{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[5,5,5,5,5,5,5,5,5],"type":"scatter"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"blue","dash":"dash"},"showlegend":false,"x":[88.0,88.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"yellow","dash":"dash"},"showlegend":false,"x":[98.0,98.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:37266.0\u003cbr\u003edisplayName:Jason Kelce\u003cbr\u003ePosition:C\u003cbr\u003eRole:Pass Block","nflId:38606.0\u003cbr\u003edisplayName:Brandon Brooks\u003cbr\u003ePosition:RG\u003cbr\u003eRole:Pass Block","nflId:39950.0\u003cbr\u003edisplayName:Lane Johnson\u003cbr\u003ePosition:RT\u003cbr\u003eRole:Pass Block","nflId:43368.0\u003cbr\u003edisplayName:Isaac Seumalo\u003cbr\u003ePosition:LG\u003cbr\u003eRole:Pass Block","nflId:45607.0\u003cbr\u003edisplayName:Greg Ward\u003cbr\u003ePosition:SLWR\u003cbr\u003eRole:Pass Route","nflId:46118.0\u003cbr\u003edisplayName:Dallas Goedert\u003cbr\u003ePosition:TE-R\u003cbr\u003eRole:Pass Route","nflId:46302.0\u003cbr\u003edisplayName:Jordan Mailata\u003cbr\u003ePosition:LT\u003cbr\u003eRole:Pass Block","nflId:47836.0\u003cbr\u003edisplayName:Miles Sanders\u003cbr\u003ePosition:HB-R\u003cbr\u003eRole:Pass Route","nflId:52429.0\u003cbr\u003edisplayName:Jalen Reagor\u003cbr\u003ePosition:RWR\u003cbr\u003eRole:Pass Route","nflId:52461.0\u003cbr\u003edisplayName:Jalen Hurts\u003cbr\u003ePosition:QB\u003cbr\u003eRole:Pass","nflId:53439.0\u003cbr\u003edisplayName:DeVonta Smith\u003cbr\u003ePosition:LWR\u003cbr\u003eRole:Pass Route"],"marker":{"color":"#004C54"},"mode":"markers","name":"PHI","x":[87.18,86.55,86.45,86.51,86.12,85.46,86.31,82.89,86.96,82.51,86.9],"y":[23.78,22.52,20.74,25.42,34.93,19.09,26.59,21.16,10.7,23.86,43.47],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:40039.0\u003cbr\u003edisplayName:Duron Harmon\u003cbr\u003ePosition:LLB\u003cbr\u003eRole:Coverage","nflId:40095.0\u003cbr\u003edisplayName:Steven Means\u003cbr\u003ePosition:ROLB\u003cbr\u003eRole:Pass Rush","nflId:42346.0\u003cbr\u003edisplayName:Dante Fowler\u003cbr\u003ePosition:LOLB\u003cbr\u003eRole:Pass Rush","nflId:42480.0\u003cbr\u003edisplayName:Grady Jarrett\u003cbr\u003ePosition:LE\u003cbr\u003eRole:Pass Rush","nflId:42497.0\u003cbr\u003edisplayName:Tyeler Davison\u003cbr\u003ePosition:NT\u003cbr\u003eRole:Pass Rush","nflId:43341.0\u003cbr\u003edisplayName:Deion Jones\u003cbr\u003ePosition:LILB\u003cbr\u003eRole:Coverage","nflId:43346.0\u003cbr\u003edisplayName:T.J. Green\u003cbr\u003ePosition:LCB\u003cbr\u003eRole:Coverage","nflId:44893.0\u003cbr\u003edisplayName:Fabian Moreau\u003cbr\u003ePosition:RCB\u003cbr\u003eRole:Coverage","nflId:46127.0\u003cbr\u003edisplayName:Isaiah Oliver\u003cbr\u003ePosition:SCBR\u003cbr\u003eRole:Coverage","nflId:46269.0\u003cbr\u003edisplayName:Foyesade Oluokun\u003cbr\u003ePosition:RLB\u003cbr\u003eRole:Coverage","nflId:53469.0\u003cbr\u003edisplayName:Richie Grant\u003cbr\u003ePosition:FS\u003cbr\u003eRole:Coverage"],"marke ...
# <div>                            <div id="fb272043-7aac-4f13-a440-a84a8272b52f" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb272043-7aac-4f13-a440-a84a8272b52f")) {                    Plotly.newPlot(                        "fb272043-7aac-4f13-a440-a84a8272b52f",                        [{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[5,5,5,5,5,5,5,5,5],"type":"scatter"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"blue","dash":"dash"},"showlegend":false,"x":[46.0,46.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"yellow","dash":"dash"},"showlegend":false,"x":[56.0,56.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:28963.0\u003cbr\u003edisplayName:Ben Roethlisberger\u003cbr\u003ePosition:QB\u003cbr\u003eRole:Pass","nflId:41236.0\u003cbr\u003edisplayName:Eric Ebron\u003cbr\u003ePosition:TE-R\u003cbr\u003eRole:Pass Route","nflId:41321.0\u003cbr\u003edisplayName:Trai Turner\u003cbr\u003ePosition:RG\u003cbr\u003eRole:Pass Block","nflId:44874.0\u003cbr\u003edisplayName:JuJu Smith-Schuster\u003cbr\u003ePosition:SLiWR\u003cbr\u003eRole:Pass Route","nflId:46129.0\u003cbr\u003edisplayName:James Washington\u003cbr\u003ePosition:SLoWR\u003cbr\u003eRole:Pass Route","nflId:46161.0\u003cbr\u003edisplayName:Chukwuma Okorafor\u003cbr\u003ePosition:RT\u003cbr\u003eRole:Pass Block","nflId:52457.0\u003cbr\u003edisplayName:Chase Claypool\u003cbr\u003ePosition:LWR\u003cbr\u003eRole:Pass Route","nflId:52543.0\u003cbr\u003edisplayName:Kevin Dotson\u003cbr\u003ePosition:LG\u003cbr\u003eRole:Pass Block","nflId:53453.0\u003cbr\u003edisplayName:Najee Harris\u003cbr\u003ePosition:HB\u003cbr\u003eRole:Pass Route","nflId:53516.0\u003cbr\u003edisplayName:Kendrick Green\u003cbr\u003ePosition:C\u003cbr\u003eRole:Pass Block","nflId:53557.0\u003cbr\u003edisplayName:Dan Moore\u003cbr\u003ePosition:LT\u003cbr\u003eRole:Pass Block"],"marker":{"color":"#FFB612"},"mode":"markers","name":"PIT","x":[40.86,44.61,44.47,43.35,45.33,44.26,44.62,44.63,37.57,45.38,44.33],"y":[23.67,19.07,22.36,30.8,35.88,20.82,43.97,25.14,23.36,23.57,26.6],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:37841.0\u003cbr\u003edisplayName:Mario Addison\u003cbr\u003ePosition:REO\u003cbr\u003eRole:Pass Rush","nflId:40107.0\u003cbr\u003edisplayName:Micah Hyde\u003cbr\u003ePosition:SCBiR\u003cbr\u003eRole:Coverage","nflId:40166.0\u003cbr\u003edisplayName:Jordan Poyer\u003cbr\u003ePosition:FS\u003cbr\u003eRole:Coverage","nflId:42331.0\u003cbr\u003edisplayName:Efe Obada\u003cbr\u003ePosition:LEO\u003cbr\u003eRole:Pass Rush","nflId:43319.0\u003cbr\u003edisplayName:Vernon Butler\u003cbr\u003ePosition:DLT\u003cbr\u003eRole:Pass Rush","nflId:44839.0\u003cbr\u003edisplayName:Tre'Davious White\u003cbr\u003ePosition:LLB\u003cbr\u003eRole:Coverage","nflId:44976.0\u003cbr\u003edisplayName:Matt Milano\u003cbr\u003ePosition:MLB\u003cbr\u003eRole:Coverage","nflId:46085.0\u003cbr\u003edisplayName:Tremaine Edmunds\u003cbr\u003ePosition:ROLB\u003cbr\u003eRole:Pass Rush","nflId:46165.0\u003cbr\u003edisplayName:Harrison Phillips\u003cbr\u003ePosition:DRT\u003cbr\u003eRole:Pass Rush","nflId:46190.0\u003cbr\u003edisplayName:Taron Johnson\u003cbr\u003ePosition:SCBoR\u003cbr\u003eRole:Coverage","nflId:46698.0\u003cbr\u003edisplayName:Levi Wallace\u003cbr\u003ePosition:RCB\u003cbr\u ...
# <div>                            <div id="e3cafca3-ea2e-4fd2-8ac0-d25fe4f54658" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3cafca3-ea2e-4fd2-8ac0-d25fe4f54658")) {                    Plotly.newPlot(                        "e3cafca3-ea2e-4fd2-8ac0-d25fe4f54658",                        [{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[5,5,5,5,5,5,5,5,5],"type":"scatter"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"blue","dash":"dash"},"showlegend":false,"x":[59.0,59.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"yellow","dash":"dash"},"showlegend":false,"x":[69.0,69.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:39684.0\u003cbr\u003edisplayName:Greg Van Roten\u003cbr\u003ePosition:RG\u003cbr\u003eRole:Pass Block","nflId:40149.0\u003cbr\u003edisplayName:Ryan Griffin\u003cbr\u003ePosition:TE-iR\u003cbr\u003eRole:Pass Route","nflId:42428.0\u003cbr\u003edisplayName:Tyler Kroft\u003cbr\u003ePosition:TE-oR\u003cbr\u003eRole:Pass Route","nflId:43433.0\u003cbr\u003edisplayName:Connor McGovern\u003cbr\u003ePosition:C\u003cbr\u003eRole:Pass Block","nflId:43586.0\u003cbr\u003edisplayName:George Fant\u003cbr\u003ePosition:RT\u003cbr\u003eRole:Pass Block","nflId:44817.0\u003cbr\u003edisplayName:Corey Davis\u003cbr\u003ePosition:LWR\u003cbr\u003eRole:Pass Route","nflId:47969.0\u003cbr\u003edisplayName:Ty Johnson\u003cbr\u003ePosition:HB-R\u003cbr\u003eRole:Pass Route","nflId:52419.0\u003cbr\u003edisplayName:Mekhi Becton\u003cbr\u003ePosition:LT\u003cbr\u003eRole:Pass Block","nflId:53431.0\u003cbr\u003edisplayName:Zach Wilson\u003cbr\u003ePosition:QB\u003cbr\u003eRole:Pass","nflId:53443.0\u003cbr\u003edisplayName:Alijah Vera-Tucker\u003cbr\u003ePosition:LG\u003cbr\u003eRole:Pass Block","nflId:53463.0\u003cbr\u003edisplayName:Elijah Moore\u003cbr\u003ePosition:SLWR\u003cbr\u003eRole:Pass Route"],"marker":{"color":"#125740"},"mode":"markers","name":"NYJ","x":[60.39,60.2,60.64,59.61,60.47,59.89,63.79,60.47,63.63,60.39,60.26],"y":[31.49,34.65,36.1,29.85,32.87,10.23,32.15,26.62,29.63,28.12,17.11],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:41341.0\u003cbr\u003edisplayName:DaQuan Jones\u003cbr\u003ePosition:DRT\u003cbr\u003eRole:Pass Rush","nflId:42368.0\u003cbr\u003edisplayName:Shaq Thompson\u003cbr\u003ePosition:LILB\u003cbr\u003eRole:Coverage","nflId:43407.0\u003cbr\u003edisplayName:Juston Burris\u003cbr\u003ePosition:FSR\u003cbr\u003eRole:Coverage","nflId:44825.0\u003cbr\u003edisplayName:Haason Reddick\u003cbr\u003ePosition:ROLB\u003cbr\u003eRole:Pass Rush","nflId:46124.0\u003cbr\u003edisplayName:Donte Jackson\u003cbr\u003ePosition:RCB\u003cbr\u003eRole:Coverage","nflId:46230.0\u003cbr\u003edisplayName:Jermaine Carter\u003cbr\u003ePosition:RILB\u003cbr\u003eRole:Coverage","nflId:47799.0\u003cbr\u003edisplayName:Brian Burns\u003cbr\u003ePosition:LOLB\u003cbr\u003eRole:Pass Rush","nflId:52415.0\u003cbr\u003edisplayName:Derrick Brown\u003cbr\u003ePosition:DLT\u003cbr\u003eRole:Pass Rush","nflId:52472.0\u003cbr\u003edisplayName:Jeremy Chinn\u003cbr\u003ePosition:LLB\u003cbr\u003eRole:Coverage","nflId:52852.0\u003cbr\u003edisplayName:Myles Hartsfield\u003cbr\u003ePosition:SCBR\u003cbr\u003eRole:Coverage","nflId:53437.0\u003cbr\u003edisplayName:Jaycee Horn\u003cbr\u003ePosition:LLB\u003cbr\u003eRole:Cove ...
# <div>                            <div id="4774d37f-6739-410c-9b82-97f42ef911be" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4774d37f-6739-410c-9b82-97f42ef911be")) {                    Plotly.newPlot(                        "4774d37f-6739-410c-9b82-97f42ef911be",                        [{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[5,5,5,5,5,5,5,5,5],"type":"scatter"},{"hoverinfo":"none","mode":"text","showlegend":false,"text":["10","20","30","40","50","40","30","20","10"],"textfont":{"color":"#ffffff","family":"Courier New, monospace","size":30},"x":[20,30,40,50,60,70,80,90,100],"y":[48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"blue","dash":"dash"},"showlegend":false,"x":[38.0,38.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"none","line":{"color":"yellow","dash":"dash"},"showlegend":false,"x":[62.0,62.0],"y":[0,53.5],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:38632.0\u003cbr\u003edisplayName:Kirk Cousins\u003cbr\u003ePosition:QB\u003cbr\u003eRole:Pass","nflId:40488.0\u003cbr\u003edisplayName:Adam Thielen\u003cbr\u003ePosition:LWR\u003cbr\u003eRole:Pass Route","nflId:43640.0\u003cbr\u003edisplayName:Rashod Hill\u003cbr\u003ePosition:LT\u003cbr\u003eRole:Pass Block","nflId:44853.0\u003cbr\u003edisplayName:Dalvin Cook\u003cbr\u003ePosition:HB-R\u003cbr\u003eRole:Pass Route","nflId:46131.0\u003cbr\u003edisplayName:Brian O'Neill\u003cbr\u003ePosition:RT\u003cbr\u003eRole:Pass Block","nflId:46226.0\u003cbr\u003edisplayName:Tyler Conklin\u003cbr\u003ePosition:TE-R\u003cbr\u003eRole:Pass Route","nflId:47801.0\u003cbr\u003edisplayName:Garrett Bradbury\u003cbr\u003ePosition:C\u003cbr\u003eRole:Pass Block","nflId:47976.0\u003cbr\u003edisplayName:Olisaemeka Udoh\u003cbr\u003ePosition:RG\u003cbr\u003eRole:Pass Block","nflId:52430.0\u003cbr\u003edisplayName:Justin Jefferson\u003cbr\u003ePosition:SLWR\u003cbr\u003eRole:Pass Route","nflId:52466.0\u003cbr\u003edisplayName:Ezra Cleveland\u003cbr\u003ePosition:LG\u003cbr\u003eRole:Pass Block","nflId:52584.0\u003cbr\u003edisplayName:K.J. Osborn\u003cbr\u003ePosition:RWR\u003cbr\u003eRole:Pass Route"],"marker":{"color":"#4F2683"},"mode":"markers","name":"MIN","x":[33.48,36.12,36.13,33.45,36.38,36.59,37.39,36.74,37.03,36.64,35.76],"y":[23.87,41.46,27.13,20.79,20.69,19.1,23.87,22.43,35.16,25.26,16.63],"type":"scatter"},{"hoverinfo":"text","hovertext":["nflId:43299.0\u003cbr\u003edisplayName:Eli Apple\u003cbr\u003ePosition:LCB\u003cbr\u003eRole:Coverage","nflId:43350.0\u003cbr\u003edisplayName:Vonn Bell\u003cbr\u003ePosition:FSL\u003cbr\u003eRole:Coverage","nflId:43455.0\u003cbr\u003edisplayName:D.J. Reader\u003cbr\u003ePosition:NRT\u003cbr\u003eRole:Pass Rush","nflId:43641.0\u003cbr\u003edisplayName:Mike Hilton\u003cbr\u003ePosition:SCBR\u003cbr\u003eRole:Coverage","nflId:44872.0\u003cbr\u003edisplayName:Chidobe Awuzie\u003cbr\u003ePosition:RCB\u003cbr\u003eRole:Coverage","nflId:44877.0\u003cbr\u003edisplayName:Larry Ogunjobi\u003cbr\u003ePosition:DLT\u003cbr\u003eRole:Pass Rush","nflId:44915.0\u003cbr\u003edisplayName:Trey Hendrickson\u003cbr\u003ePosition:REO\u003cbr\u003eRole:Pass Rush","nflId:46123.0\u003cbr\u003edisplayName:Jessie Bates\u003cbr\u003ePosition:FSR\u003cbr\u003eRole:Coverage","nflId:46146.0\u003cbr\u003edisplayName:Sam Hubbard\u003cbr\u003ePosition:LEO\u003cbr\u003eRole:Pass Rush","nflId:52473.0\u003cbr\u003edisplayName:Logan Wilson\u003cbr\u003ePosition:LLB\u003cbr\u003eRole:Coverage","nflId:52515.0\u003cbr\u003edisplayName:Akeem Davis-Gaither\u003cbr\u003ePosition:RILB\u003cbr\u003eRole:Coverag ...
